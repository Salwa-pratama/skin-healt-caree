# %% [markdown]
# # Acne Classification Using CNN
# ## Goal:
# Build a deep learning model to classify acne types using a CNN model, while addressing dataset imbalance through oversampling and augmentation.

# %% [markdown]
# ## ----------------------------
# ## 1. IMPORTS
# ## ----------------------------

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
from sklearn.utils.class_weight import compute_class_weight
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## 📦 2. Download Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tiswan14/acne-dataset-image")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\nande\.cache\kagglehub\datasets\tiswan14\acne-dataset-image\versions\1

# %% [markdown]
# ## 📂 3. Dataset Paths & Parameters

# %%
base_dir = r"C:\Users\nande\.cache\kagglehub\datasets\tiswan14\acne-dataset-image\versions\1\AcneDataset"
train_dir = os.path.join(base_dir, "train")
valid_dir = os.path.join(base_dir, "valid")
test_dir  = os.path.join(base_dir, "test")

# %% [markdown]
# ## 🧠 4. Load Datasets

# %%
# ----------------------------
# PARAMETERS
# ----------------------------
# Jumlah berapa kali belajar (32 kali)
BATCH_SIZE = 50
# Original image size
# Resize semua gambar
IMAGE_SIZE = 128
# Adjustment image size
# IMAGE_SIZE = 60

# ----------------------------
# LOAD DATASETS
# ----------------------------
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, label_mode='int', image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, shuffle=True
)

valid_ds = tf.keras.preprocessing.image_dataset_from_directory(
    valid_dir, label_mode='int', image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, shuffle=False
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir, label_mode='int', image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, shuffle=False
)

class_names = train_ds.class_names
print("Classes:", class_names)
import json
# export classname
with open("class_names.json", "w") as f:
    json.dump(class_names, f)
# Out:
# Found 2778 files belonging to 5 classes.
# Found 921 files belonging to 5 classes.
# Found 918 files belonging to 5 classes.
# Classes: ['Blackheads', 'Cyst', 'Papules', 'Pustules', 'Whiteheads']

# %% [markdown]
# ## 🖼️ 5. Visualize Sample Images

# %%
for image, label in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(image[i].numpy().astype("uint8"))

        label_index = label[i].numpy()
        plt.title(class_names[label_index])

        plt.axis("off")

# %% [markdown]
# ## 📊 6. Class Distribution

# %%
for folder in ['train', 'valid', 'test']:
    folder_path = os.path.join(base_dir, folder)
    for cls in os.listdir(folder_path):
        cls_path = os.path.join(folder_path, cls)
        if os.path.isdir(cls_path):  # Only count directories
            print(f"{folder}/{cls}:", len(os.listdir(cls_path)))
# Out:
# train/Blackheads: 735
# train/Cyst: 645
# train/Papules: 621
# train/Pustules: 584
# train/Whiteheads: 193
# valid/Blackheads: 240
# valid/Cyst: 206
# valid/Papules: 209
# valid/Pustules: 217
# valid/Whiteheads: 49
# test/Blackheads: 265
# test/Cyst: 189
# test/Papules: 202
# test/Pustules: 205
# test/Whiteheads: 57

# %% [markdown]
# ### 📌 Observation:
# Whiteheads (193 images) are underrepresented, which can bias the model.
# We'll fix this using oversampling and augmentation.

# %% [markdown]
# ## ⚖️ 7. Compute Class Weights

# %%
counts = [735, 645, 621, 584, 193]
classes = np.array([0,1,2,3,4])
y = np.repeat(classes, counts)
class_weight_dict = dict(zip(classes, compute_class_weight('balanced', classes=classes, y=y)))
print("Class weights:", class_weight_dict)
# Out:
# Class weights: {np.int64(0): np.float64(0.7559183673469387), np.int64(1): np.float64(0.8613953488372093), np.int64(2): np.float64(0.8946859903381642), np.int64(3): np.float64(0.9513698630136986), np.int64(4): np.float64(2.8787564766839377)}

# %% [markdown]
# ## 🔧 8. Preprocessing & Normalization

# %%
normalization_layer = Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
valid_ds = valid_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# ## 🔁 9. Data Augmentation

# %%
data_augmentation = Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation(0.15),
    RandomZoom(0.15)
])

# %% [markdown]
# ## 🔄 10. Oversampling Minority Class (Whiteheads)

# %%
# Unbatch the dataset
train_ds_unbatched = train_ds.unbatch()

# Split dataset by class
class_datasets = []
for i in range(len(class_names)):
    class_datasets.append(train_ds_unbatched.filter(lambda x, y: y==i))

# Oversample minority class (Whiteheads, index 4)
target_count = max(counts)
minority_index = 4
repeat_times = target_count // counts[minority_index]
remainder = target_count % counts[minority_index]

oversampled_class = class_datasets[minority_index].repeat(repeat_times)
oversampled_class = oversampled_class.concatenate(class_datasets[minority_index].take(remainder))
class_datasets[minority_index] = oversampled_class

# Combine all classes
balanced_ds = class_datasets[0]
for ds in class_datasets[1:]:
    balanced_ds = balanced_ds.concatenate(ds)

# Shuffle, augment, and batch correctly
balanced_ds = balanced_ds.shuffle(5000)
balanced_ds = balanced_ds.map(lambda x, y: (data_augmentation(x, training=True), y))
balanced_ds = balanced_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### ✅ Result:
# The dataset is now balanced across all acne types.

# %%
valid_ds = valid_ds.cache().prefetch(tf.data.AUTOTUNE)
test_ds  = test_ds.cache().prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## 🧰 11. Build CNN Model

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMAGE_SIZE, IMAGE_SIZE,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(256, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),
    Dense(len(class_names), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 667,845 (2.55 MB)
#  Trainable params: 667,845 (2.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 🏋️‍♂️ 12. Train Model

# %%
# ----------------------------
# CALLBACKS
# ----------------------------
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

# ----------------------------
# TRAIN MODEL
# ----------------------------
history = model.fit(
    balanced_ds,
    validation_data=valid_ds,
    epochs=60,
    # epochs=10,
    class_weight=class_weight_dict,
    callbacks=[early_stop, lr_scheduler],
    verbose=2
)
model.save("acne_model.keras")
# Out:
# Epoch 1/60
# 67/67 - 59s - 882ms/step - accuracy: 0.2449 - loss: 1.8185 - val_accuracy: 0.1183 - val_loss: 1.8961 - learning_rate: 0.0010
# Epoch 2/60
# 67/67 - 52s - 771ms/step - accuracy: 0.3048 - loss: 1.6039 - val_accuracy: 0.1488 - val_loss: 1.7239 - learning_rate: 0.0010
# Epoch 3/60
# 67/67 - 49s - 739ms/step - accuracy: 0.3277 - loss: 1.5373 - val_accuracy: 0.1564 - val_loss: 1.9132 - learning_rate: 0.0010
# Epoch 4/60
# 67/67 - 50s - 753ms/step - accuracy: 0.3419 - loss: 1.5039 - val_accuracy: 0.2237 - val_loss: 1.7210 - learning_rate: 0.0010
# Epoch 5/60
# 67/67 - 50s - 746ms/step - accuracy: 0.3563 - loss: 1.4464 - val_accuracy: 0.2410 - val_loss: 1.6598 - learning_rate: 0.0010
# Epoch 6/60
# 67/67 - 50s - 750ms/step - accuracy: 0.3780 - loss: 1.3826 - val_accuracy: 0.2671 - val_loss: 1.5188 - learning_rate: 0.0010
# Epoch 7/60
# 67/67 - 51s - 763ms/step - accuracy: 0.3786 - loss: 1.3913 - val_accuracy: 0.2964 - val_loss: 1.5594 - learning_rate: 0.0010
# Epoch 8/60
# 67/67 - 79s - 1s/step - accuracy: 0.3750 - loss: 1.3718 - val_accuracy: 0.2649 - val_loss: 1.6511 - learning_rate: 0.0010
# Epoch 9/60
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 - 64s - 961ms/step - accuracy: 0.4111 - loss: 1.2912 - val_accuracy: 0.2932 - val_loss: 1.5239 - learning_rate: 0.0010
# Epoch 10/60
# 67/67 - 59s - 879ms/step - accuracy: 0.4373 - loss: 1.1984 - val_accuracy: 0.3724 - val_loss: 1.4167 - learning_rate: 5.0000e-04
# Epoch 11/60
# 67/67 - 64s - 956ms/step - accuracy: 0.4590 - loss: 1.1620 - val_accuracy: 0.3746 - val_loss: 1.4445 - learning_rate: 5.0000e-04
# Epoch 12/60
# 67/67 - 58s - 866ms/step - accuracy: 0.4735 - loss: 1.1147 - val_accuracy: 0.3855 - val_loss: 1.4154 - learning_rate: 5.0000e-04
# Epoch 13/60
# 67/67 - 80s - 1s/step - accuracy: 0.4934 - loss: 1.0848 - val_accuracy: 0.4343 - val_loss: 1.3246 - learning_rate: 5.0000e-04
# Epoch 14/60
# 67/67 - 59s - 877ms/step - accuracy: 0.5099 - loss: 1.0484 - val_accuracy: 0.3996 - val_loss: 1.4013 - learning_rate: 5.0000e-04
# Epoch 15/60
# 67/67 - 70s - 1s/step - accuracy: 0.5193 - loss: 1.0423 - val_accuracy: 0.4615 - val_loss: 1.2733 - learning_rate: 5.0000e-04
# Epoch 16/60
# 67/67 - 48s - 721ms/step - accuracy: 0.4994 - loss: 1.0686 - val_accuracy: 0.4506 - val_loss: 1.3107 - learning_rate: 5.0000e-04
# Epoch 17/60
# 67/67 - 52s - 775ms/step - accuracy: 0.5491 - loss: 0.9849 - val_accuracy: 0.4506 - val_loss: 1.2859 - learning_rate: 5.0000e-04
# Epoch 18/60
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 - 76s - 1s/step - accuracy: 0.5527 - loss: 0.9712 - val_accuracy: 0.4528 - val_loss: 1.3021 - learning_rate: 5.0000e-04
# Epoch 19/60
# 67/67 - 54s - 812ms/step - accuracy: 0.5798 - loss: 0.9024 - val_accuracy: 0.5060 - val_loss: 1.2599 - learning_rate: 2.5000e-04
# Epoch 20/60
# 67/67 - 50s - 751ms/step - accuracy: 0.5822 - loss: 0.8893 - val_accuracy: 0.5179 - val_loss: 1.1998 - learning_rate: 2.5000e-04
# Epoch 21/60
# 67/67 - 50s - 748ms/step - accuracy: 0.5961 - loss: 0.8691 - val_accuracy: 0.4984 - val_loss: 1.2910 - learning_rate: 2.5000e-04
# Epoch 22/60
# 67/67 - 50s - 753ms/step - accuracy: 0.5997 - loss: 0.8774 - val_accuracy: 0.5255 - val_loss: 1.1976 - learning_rate: 2.5000e-04
# Epoch 23/60
# 67/67 - 78s - 1s/step - accuracy: 0.6084 - loss: 0.8603 - val_accuracy: 0.5342 - val_loss: 1.1543 - learning_rate: 2.5000e-04
# Epoch 24/60
# 67/67 - 49s - 736ms/step - accuracy: 0.6127 - loss: 0.8323 - val_accuracy: 0.5527 - val_loss: 1.1225 - learning_rate: 2.5000e-04
# Epoch 25/60
# 67/67 - 49s - 731ms/step - accuracy: 0.6051 - loss: 0.8564 - val_accuracy: 0.5494 - val_loss: 1.1250 - learning_rate: 2.5000e-04
# Epoch 26/60
# 67/67 - 49s - 728ms/step - accuracy: 0.6286 - loss: 0.8129 - val_accuracy: 0.5689 - val_loss: 1.0883 - learning_rate: 2.5000e-04
# Epoch 27/60
# 67/67 - 52s - 778ms/step - accuracy: 0.6247 - loss: 0.8391 - val_accuracy: 0.5548 - val_loss: 1.1137 - learning_rate: 2.5000e-04
# Epoch 28/60
# 67/67 - 51s - 760ms/step - accuracy: 0.6319 - loss: 0.7948 - val_accuracy: 0.5613 - val_loss: 1.1032 - learning_rate: 2.5000e-04
# Epoch 29/60
# 67/67 - 50s - 747ms/step - accuracy: 0.6380 - loss: 0.7843 - val_accuracy: 0.5896 - val_loss: 1.0600 - learning_rate: 2.5000e-04
# Epoch 30/60
# 67/67 - 50s - 747ms/step - accuracy: 0.6422 - loss: 0.7947 - val_accuracy: 0.6026 - val_loss: 1.0431 - learning_rate: 2.5000e-04
# Epoch 31/60
# 67/67 - 81s - 1s/step - accuracy: 0.6461 - loss: 0.7649 - val_accuracy: 0.5885 - val_loss: 1.0393 - learning_rate: 2.5000e-04
# Epoch 32/60
# 67/67 - 83s - 1s/step - accuracy: 0.6319 - loss: 0.7931 - val_accuracy: 0.5624 - val_loss: 1.0855 - learning_rate: 2.5000e-04
# Epoch 33/60
# 67/67 - 50s - 747ms/step - accuracy: 0.6410 - loss: 0.7801 - val_accuracy: 0.6048 - val_loss: 1.0037 - learning_rate: 2.5000e-04
# Epoch 34/60
# 67/67 - 51s - 756ms/step - accuracy: 0.6569 - loss: 0.7463 - val_accuracy: 0.6091 - val_loss: 0.9976 - learning_rate: 2.5000e-04
# Epoch 35/60
# 67/67 - 51s - 755ms/step - accuracy: 0.6660 - loss: 0.7283 - val_accuracy: 0.5950 - val_loss: 0.9839 - learning_rate: 2.5000e-04
# Epoch 36/60
# 67/67 - 51s - 765ms/step - accuracy: 0.6690 - loss: 0.7287 - val_accuracy: 0.6211 - val_loss: 0.9486 - learning_rate: 2.5000e-04
# Epoch 37/60
# 67/67 - 62s - 931ms/step - accuracy: 0.6711 - loss: 0.7159 - val_accuracy: 0.6156 - val_loss: 0.9840 - learning_rate: 2.5000e-04
# Epoch 38/60
# 67/67 - 100s - 1s/step - accuracy: 0.6717 - loss: 0.7004 - val_accuracy: 0.6352 - val_loss: 0.9471 - learning_rate: 2.5000e-04
# Epoch 39/60
# 67/67 - 79s - 1s/step - accuracy: 0.6819 - loss: 0.7111 - val_accuracy: 0.6298 - val_loss: 0.9345 - learning_rate: 2.5000e-04
# Epoch 40/60
# 67/67 - 81s - 1s/step - accuracy: 0.6798 - loss: 0.6971 - val_accuracy: 0.6450 - val_loss: 0.9493 - learning_rate: 2.5000e-04
# Epoch 41/60
# 67/67 - 88s - 1s/step - accuracy: 0.6895 - loss: 0.7220 - val_accuracy: 0.6547 - val_loss: 0.9649 - learning_rate: 2.5000e-04
# Epoch 42/60
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 67/67 - 126s - 2s/step - accuracy: 0.6937 - loss: 0.6656 - val_accuracy: 0.6221 - val_loss: 0.9653 - learning_rate: 2.5000e-04
# Epoch 43/60
# 67/67 - 52s - 782ms/step - accuracy: 0.7060 - loss: 0.6511 - val_accuracy: 0.6688 - val_loss: 0.8775 - learning_rate: 1.2500e-04
# Epoch 44/60
# 67/67 - 51s - 761ms/step - accuracy: 0.7178 - loss: 0.6325 - val_accuracy: 0.6721 - val_loss: 0.8689 - learning_rate: 1.2500e-04
# Epoch 45/60
# 67/67 - 49s - 735ms/step - accuracy: 0.7268 - loss: 0.6216 - val_accuracy: 0.6819 - val_loss: 0.8615 - learning_rate: 1.2500e-04
# Epoch 46/60
# 67/67 - 50s - 744ms/step - accuracy: 0.7253 - loss: 0.6158 - val_accuracy: 0.6808 - val_loss: 0.8325 - learning_rate: 1.2500e-04
# Epoch 47/60
# 67/67 - 53s - 785ms/step - accuracy: 0.7175 - loss: 0.6261 - val_accuracy: 0.6591 - val_loss: 0.8592 - learning_rate: 1.2500e-04
# Epoch 48/60
# 67/67 - 113s - 2s/step - accuracy: 0.7265 - loss: 0.6144 - val_accuracy: 0.6884 - val_loss: 0.8452 - learning_rate: 1.2500e-04
# Epoch 49/60
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 - 85s - 1s/step - accuracy: 0.7337 - loss: 0.5928 - val_accuracy: 0.6851 - val_loss: 0.8437 - learning_rate: 1.2500e-04
# Epoch 50/60
# 67/67 - 113s - 2s/step - accuracy: 0.7410 - loss: 0.5859 - val_accuracy: 0.6949 - val_loss: 0.8075 - learning_rate: 6.2500e-05
# Epoch 51/60
# 67/67 - 85s - 1s/step - accuracy: 0.7386 - loss: 0.5820 - val_accuracy: 0.6949 - val_loss: 0.8137 - learning_rate: 6.2500e-05
# Epoch 52/60
# 67/67 - 82s - 1s/step - accuracy: 0.7392 - loss: 0.5854 - val_accuracy: 0.6938 - val_loss: 0.8103 - learning_rate: 6.2500e-05
# Epoch 53/60
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 - 62s - 921ms/step - accuracy: 0.7434 - loss: 0.5836 - val_accuracy: 0.6873 - val_loss: 0.8207 - learning_rate: 6.2500e-05
# Epoch 54/60
# 67/67 - 69s - 1s/step - accuracy: 0.7410 - loss: 0.5697 - val_accuracy: 0.6992 - val_loss: 0.7929 - learning_rate: 3.1250e-05
# Epoch 55/60
# 67/67 - 72s - 1s/step - accuracy: 0.7503 - loss: 0.5694 - val_accuracy: 0.6938 - val_loss: 0.7946 - learning_rate: 3.1250e-05
# Epoch 56/60
# 67/67 - 61s - 906ms/step - accuracy: 0.7693 - loss: 0.5549 - val_accuracy: 0.7025 - val_loss: 0.7868 - learning_rate: 3.1250e-05
# Epoch 57/60
# 67/67 - 57s - 856ms/step - accuracy: 0.7533 - loss: 0.5638 - val_accuracy: 0.7014 - val_loss: 0.8020 - learning_rate: 3.1250e-05
# Epoch 58/60
# 67/67 - 80s - 1s/step - accuracy: 0.7488 - loss: 0.5707 - val_accuracy: 0.7014 - val_loss: 0.7961 - learning_rate: 3.1250e-05
# Epoch 59/60
# 67/67 - 51s - 758ms/step - accuracy: 0.7593 - loss: 0.5580 - val_accuracy: 0.7058 - val_loss: 0.7838 - learning_rate: 3.1250e-05
# Epoch 60/60
# 67/67 - 51s - 760ms/step - accuracy: 0.7470 - loss: 0.5698 - val_accuracy: 0.7068 - val_loss: 0.7890 - learning_rate: 3.1250e-05

# %% [markdown]
# ## 📈 13. Evaluate Model

# %%
test_loss, test_acc = model.evaluate(test_ds)
print("Test Accuracy:", test_acc)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.6743 - loss: 0.9208
# Test Accuracy: 0.6742919683456421

# %% [markdown]
# ## 🔍 14. Confusion Matrix & Classification Report

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get true and predicted labels for test set
y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step

# %%
# ----------------------------
# CONFUSION MATRIX
# ----------------------------
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
# ----------------------------
# CLASSIFICATION REPORT
# ----------------------------
report = classification_report(y_true, y_pred, target_names=class_names)
print("\nClassification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#   Blackheads       0.77      0.71      0.74       265
#         Cyst       0.57      0.81      0.67       189
#      Papules       0.63      0.49      0.55       202
#     Pustules       0.66      0.60      0.63       205
#   Whiteheads       0.90      0.98      0.94        57
#
#     accuracy                           0.67       918
#    macro avg       0.71      0.72      0.71       918
# weighted avg       0.68      0.67      0.67       918

# %% [markdown]
# ## 📊 15. Accuracy and Loss Curves

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
